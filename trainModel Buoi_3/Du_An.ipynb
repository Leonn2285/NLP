# %% [markdown]
# **ĐỒ ÁN**
# 1. Bài toán
#
# Supervise (Tạo bộ dữ liệu thủ công)
#  + Test classification (domain) ứng dụng đc trong 1 lĩnh vực : 2
#  + Sent analysis (aspect) : 2
#  + NER/IE/RE : 3
#  + POS : 2
#
# Unsupervise, Semi - supervise
#  + Topic Modelling --> Clustering : 2
#
# 2. Yêu cầu mô hình
# * Conventional  ML - 3 mô hình (logistic, SVM, ..) (càng nhiều càng tốt)
# * Deep Learning
#
# 3. Feature representation
# - Cực lưu ý: Áp dụng giống nhau cho 4 mô hình
#
# 40-45 trang là tối đa cho Report
