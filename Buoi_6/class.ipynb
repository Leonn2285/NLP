# %%
import nltk

# %%
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/leonnn/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/leonnn/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
input = "This is a sample for NLP preprocessing."
token = nltk.word_tokenize(input)
nltk.pos_tag(token)
# Out:
# [('This', 'DT'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('sample', 'NN'),
#  ('for', 'IN'),
#  ('NLP', 'NNP'),
#  ('preprocessing', 'NN'),
#  ('.', '.')]

# %%
input_vi = "Đây là một ví dụ về tiền xử lý NLP."
nltk.pos_tag(nltk.word_tokenize(input_vi))
# Out:
# [('Đây', 'JJ'),
#  ('là', 'NN'),
#  ('một', 'NN'),
#  ('ví', 'NN'),
#  ('dụ', 'NN'),
#  ('về', 'NN'),
#  ('tiền', 'NN'),
#  ('xử', 'NNP'),
#  ('lý', 'NN'),
#  ('NLP', 'NNP'),
#  ('.', '.')]

# %%
import underthesea
underthesea.pos_tag(input_vi)
# Out:
# [('Đây', 'P'),
#  ('là', 'V'),
#  ('một', 'M'),
#  ('ví dụ', 'N'),
#  ('về', 'E'),
#  ('tiền', 'N'),
#  ('xử lý', 'V'),
#  ('NLP', 'Np'),
#  ('.', 'CH')]

# %%
# %pip install -U easynmt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install fasttext
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langid
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langdetect
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import easynmt

# %%
# %pip install sentencepiece protobuf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install sentencepiece
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
model = easynmt.EasyNMT('opus-mt')
text_run = 'This is an instance for processing of NLP'
model_translate = model.translate(text_run, target_lang='vi')

# %%
import nltk
result = nltk.pos_tag(nltk.word_tokenize(text_run))

# %%
for pair in result: 
    print((pair[0], model.translate(pair[0], target_lang='vi'), pair[1]))
# Out:
# ('This', 'Chỉ', 'DT')
# ('is', '& Xuất ra danh sách', 'VBZ')
# ('an', 'Tên:', 'DT')
# ('an', 'Tên:', 'DT')
# ...
